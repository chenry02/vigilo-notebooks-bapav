# %%
import pandas as pd

df = pd.read_csv('../data_collection/dataframe.csv')

df.head(10)
# Out:
#       token  coordinates_lat  coordinates_lon  \
# 0  371F7590        48.385903        -4.511905
# 1  32FC146C        48.434540        -4.501101
# 2  EB3F1768        48.386733        -4.470935
# 3  CE8F870B        48.387475        -4.477063
# 4  F4D753AA        48.402215        -4.492029
# 5  40FBF5B1        48.402112        -4.488734
# 6  BF380A40        48.390315        -4.491557
# 7  FAA931F6        48.403994        -4.497075
# 8  6A2F06A8        48.404106        -4.496347
# 9  DFE92076        48.400295        -4.480252
#
#                             address                                 comment  \
# 0  Rue de la Frégate Laplace, Brest      Proposer un contre-sens cyclable ?
# 1        Chemin de Lostennic, Brest                   Traversée dangereuse
# 2   rd point herman melville, Brest                          pb d insertion
# 3         Rue Poullic Al Lor, Brest                     Absence de trottoir
# 4          Rue Marcel Sembat, Brest  Trottoir impraticable depuis des mois.
# 5        Rue Auguste Kervern, Brest        Aménagements cyclables prévus ?
# 6               Rue de Lyon, Brest.                 Pas de bande cyclable.
# 7        Professeur Langevin, Brest              absence de bande cyclable.
# 8           Joseph le Borgne, Brest                  Aménagements prévus ?
# 9            Rue Paul Masson, Brest               Manque un passage piéton
#
#                                          explanation        time  status  \
# 0  Pourquoi ne pas proposer un contre-sens cyclab...  1686144720       1
# 1  Il est très dangereux de traverser la rue du T...  1685428380       0
# 2  l aménagement est super,  une grande avancée a...  1684163460       0
# 3                                                NaN  1681050960       0
# 4  Trottoir défoncé par les camions livrant des m...  1675073700       0
# 5  Aménagements cyclables de prévus ? \nRappelons...  1665509400       3
# 6  rue assez large ne disposant pas d'aménagement...  1665249660       0
# 7  Il n'y a pas d'aménagements cyclables. Le sens...  1665132240       0
# 8  Rue actuellement en travaux. L'article de Loi ...  1665132240       0
# 9                                                NaN  1662741480       0
#
#    group  categorie  approved cityname
# 0      0          8         1    Brest
# 1      0          8         1    Brest
# 2      0          8         1    Brest
# 3      0          8         1    Brest
# 4      0          8         1    Brest
# 5      0          8         1    Brest
# 6      0          8         1   Brest.
# 7      0          8         1    Brest
# 8      0          8         1    Brest
# 9      0          8         1    Brest

# %%
import matplotlib.pyplot as plt

# Récupération des catégories
df_categories = pd.read_csv('../data_collection/categories.csv')

# Enregistrements de la catégorie pour chaque signalement
incidents = df['categorie'].tolist()


# Créer un histogramme
plt.hist(incidents, range=(0,10), color='blue', edgecolor='black')  # bins détermine le nombre de barres dans l'histogramme

# Ajouter des labels et un titre
plt.xlabel('Numéro de catégorie')
plt.ylabel('Nombre de signalements')
plt.title('Nombre de signalements par catégorie')

# Afficher l'histogramme
plt.show()

# Affichage des categories
df_categories.head(10)
# Out:
#                            Catégories
# 0               Absence d'aménagement
# 1               Aménagement mal conçu
# 2                  Défaut d'entretien
# 3  Absence d'arceaux de stationnement
# 4            Véhicule ou objet gênant
# 5           Accident, chute, incident
# 6             Signalisation, marquage
# 7  Incivilité récurrente sur la route
# 8          Vol ou dégradation de vélo
# 9                               Autre
