# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests

plt.style.use('ggplot')

requests

df = pd.DataFrame(requests.get('https://vigilo.bapav.org/get_issues.php?').json())

# %%
# Récupération des catégories
df_categories = pd.read_csv('../data_collection/categories.csv')

incidents = df['categorie'].value_counts().to_frame().reset_index()
incidents.columns = ['categorie', 'nombre d\'incidents']

sns.barplot(y='nombre d\'incidents', x='categorie', data=incidents)
# Out:
# <Axes: xlabel='categorie', ylabel="nombre d'incidents">
